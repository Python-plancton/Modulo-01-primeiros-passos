# %% [markdown]
# # Módulo 01 - Variáveis e Tipos · Exercícios
#
# Antes de cada bloco de exercícios abaixo, leia o tópico correspondente em
# `01_variaveis_tipos.md`. Tente resolver sozinha antes de olhar o
# `gabarito.py`.
#
# - **Nível 1** - conceito puro, sem pegadinha
# - **Nível 2** - combinação de conceitos
# - **Nível 3** - desafio estilo LeetCode (função com entrada/saída definida), no final do notebook
#
# Rode cada célula com `Shift + Enter`.

# %% [markdown]
# ## Tópico 1 - Conceito de variável

# %% [markdown]
# **Nível 1.1** - Crie uma variável chamada `cidade` com o valor `"Ribeirão Preto"` e imprima ela.

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 1.2** - Crie duas variáveis, `preco` (100) e `quantidade` (3).
# Crie uma terceira variável `total` que seja o produto das duas e imprima `total`.
#
# Saída esperada: `300`

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.1** - Uma variável `saldo` começa com `500`. Depois de um saque de `120`,
# reatribua `saldo` para refletir o novo valor e imprima o resultado.
#
# Saída esperada: `380`

# %%
saldo = 500
# SUA SOLUÇÃO AQUI (reatribua saldo)

# %% [markdown]
# ## Tópico 2 - Nomes de variáveis

# %% [markdown]
# **Nível 1.1** - Dos nomes abaixo, alguns são **inválidos** em Python.
# Numa string (comentário), escreva ao lado de cada um se é `válido` ou `inválido` e por quê:
#
# ```
# 1valor
# nome_cliente
# class
# Total-Vendas
# total_vendas_2024
# ```

# %%
# Escreva sua resposta como comentários:
# 1valor -> 
# nome_cliente -> 
# class -> 
# Total-Vendas -> 
# total_vendas_2024 ->

# %% [markdown]
# **Nível 2.1** - Reescreva as variáveis abaixo seguindo a convenção `snake_case`
# (minúsculas, separadas por `_`) e crie elas com um valor qualquer:
#
# ```
# NomeCompleto
# DATAdeNascimento
# valorTotalDaCompra
# ```

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# ## Tópico 3 - Variáveis numéricas

# %% [markdown]
# **Nível 1.1** - Crie a variável `nota` com valor `8.5` e imprima o tipo dela usando `type()`.
#
# Saída esperada: `<class 'float'>`

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 1.2** - Calcule e imprima os resultados de:
# - `17 / 5`
# - `17 // 5`
# - `17 % 5`
# - `17 ** 2`

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.1** - Um estoque tem `137` unidades de um produto, vendidas em caixas de `12` unidades.
# Calcule quantas caixas fechadas dá para montar (`caixas`) e quantas unidades sobram soltas (`sobra`).
# Imprima os dois valores.
#
# Saída esperada: `caixas = 11`, `sobra = 5`

# %%
estoque = 137
tamanho_caixa = 12
# SUA SOLUÇÃO AQUI

# %% [markdown]
# ## Tópico 4 - Variáveis do tipo lógico (bool)

# %% [markdown]
# **Nível 1.1** - Crie a variável `maior_idade` que seja `True` se `idade >= 18`, para `idade = 20`.
# Imprima `maior_idade`.

# %%
idade = 20
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 1.2** - Dadas as variáveis abaixo, imprima o resultado de cada comparação:
# - `a == b`
# - `a != b`
# - `a > b`
# - `b >= a`

# %%
a = 15
b = 9
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.1** - Uma transação é considerada **suspeita** se o valor for maior que `5000`
# **e** o país for diferente de `"BR"`. Crie a variável `suspeita` (bool) para os dados abaixo
# e imprima o resultado.
#
# Saída esperada: `True`

# %%
valor_transacao = 7200
pais = "US"
# SUA SOLUÇÃO AQUI (use and)

# %% [markdown]
# **Nível 2.2** - Uma pessoa pode votar se tem `16` anos ou mais, **ou** se já tem título de eleitor
# mesmo sendo mais nova (caso raro, mas didático). Crie `pode_votar` usando `or` e imprima.
#
# Dados: `idade = 15`, `tem_titulo = True` → saída esperada: `True`

# %%
idade = 15
tem_titulo = True
# SUA SOLUÇÃO AQUI (use or)

# %% [markdown]
# ## Tópico 5 - Variáveis string

# %% [markdown]
# **Nível 1.1** - Crie a variável `produto = "Notebook Gamer"` e imprima seu tamanho com `len()`.

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 1.2** - Para a string `codigo = "VG-2024-BR"`, imprima:
# - o primeiro caractere
# - o último caractere (usando índice negativo)

# %%
codigo = "VG-2024-BR"
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.1 (concatenação e composição)** - Dadas `nome = "Larissa"` e `cargo = "Analista de Dados"`,
# monte a frase `"Larissa atua como Analista de Dados"`:
# - primeiro usando `+` (concatenação)
# - depois usando f-string (composição)
#
# Imprima as duas versões.

# %%
nome = "Larissa"
cargo = "Analista de Dados"
# concatenação
# SUA SOLUÇÃO AQUI

# f-string
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.2 (slicing)** - Para `transacao_id = "TRX-98213-VG"`, use fatiamento para extrair:
# - só o número `"98213"`
# - a string inteira invertida
#
# Saída esperada: `98213` e `GV-31289-XRT`

# %%
transacao_id = "TRX-98213-VG"
# SUA SOLUÇÃO AQUI

# %% [markdown]
# ## Tópico 6 - Sequência de execução e rastreamento

# %% [markdown]
# **Nível 1.1** - Sem rodar o código, escreva num comentário o valor final de `x` linha a linha
# (monte a tabela de rastreamento mentalmente). Depois rode a célula e confira se acertou.
#
# ```python
# x = 10
# x = x + 5
# x = x * 2
# x = x - 3
# ```

# %%
# Sua previsão (comentário):
# linha 1: x = 
# linha 2: x = 
# linha 3: x = 
# linha 4: x = 

x = 10
x = x + 5
x = x * 2
x = x - 3
print(x)

# %% [markdown]
# **Nível 2.1** - Rastreie o valor de `saldo` e `taxa` linha a linha antes de rodar.
# Depois confira executando a célula.
#
# ```python
# saldo = 1000
# taxa = 0.02
# saldo = saldo - (saldo * taxa)
# taxa = taxa + 0.01
# saldo = saldo - (saldo * taxa)
# ```

# %%
saldo = 1000
taxa = 0.02
saldo = saldo - (saldo * taxa)
taxa = taxa + 0.01
saldo = saldo - (saldo * taxa)
print(saldo, taxa)

# %% [markdown]
# ## Tópico 7 - Entrada de dados

# %% [markdown]
# **Nível 1.1** - Use `input()` para perguntar o nome da pessoa e imprima
# `"Olá, <nome>!"` usando f-string.

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 1.2** - Peça a idade da pessoa com `input()`, converta para `int` e imprima
# o tipo da variável depois da conversão (deve ser `<class 'int'>`).

# %%
# SUA SOLUÇÃO AQUI

# %% [markdown]
# **Nível 2.1 (erros comuns)** - O código abaixo tem um erro proposital. Rode, leia a
# mensagem de erro (`Traceback`) e depois corrija a célula.
#
# ```python
# idade = input("Digite sua idade: ")
# print(idade + 1)
# ```
#
# Dica: o problema é de tipo — `idade` é `str`, e `1` é `int`.

# %%
# Versão com erro (rode para ver o Traceback, depois corrija abaixo):
# idade = input("Digite sua idade: ")
# print(idade + 1)

# SUA CORREÇÃO AQUI

# %% [markdown]
# ## Desafios - Nível 3 (estilo LeetCode)
#
# Nos exercícios abaixo, complete a função conforme a assinatura indicada.
# Os `print()` já mostram o resultado esperado — rode a célula e compare.

# %% [markdown]
# ### Desafio 1 - `classificar_idade`
#
# Recebe uma idade (`int`) e retorna uma `string`:
# - `"crianca"` se idade < 12
# - `"adolescente"` se 12 <= idade < 18
# - `"adulto"` se idade >= 18

# %%
def classificar_idade(idade: int) -> str:
    # SUA SOLUÇÃO AQUI
    pass

# Casos de teste
print(classificar_idade(8))    # crianca
print(classificar_idade(15))   # adolescente
print(classificar_idade(30))   # adulto

# %% [markdown]
# ### Desafio 2 - `inverter_texto`
#
# Recebe uma string e retorna ela invertida, usando slicing.

# %%
def inverter_texto(texto: str) -> str:
    # SUA SOLUÇÃO AQUI
    pass

# Casos de teste
print(inverter_texto("python"))     # nohtyp
print(inverter_texto("dados"))      # sodad

# %% [markdown]
# ### Desafio 3 - `extrair_id_numerico`
#
# Recebe um código de transação no formato `"TRX-<numero>-<pais>"` (ex: `"TRX-98213-VG"`)
# e retorna só a parte numérica como `string`, usando `len()` e slicing
# (sem usar `.split()`, que ainda não vimos).
#
# Dica: o número sempre tem 5 dígitos, e vem sempre logo depois de `"TRX-"`.

# %%
def extrair_id_numerico(codigo: str) -> str:
    # SUA SOLUÇÃO AQUI
    pass

# Casos de teste
print(extrair_id_numerico("TRX-98213-VG"))  # 98213
print(extrair_id_numerico("TRX-00042-BR"))  # 00042

# %% [markdown]
# ### Desafio 4 - `transacao_suspeita`
#
# Recebe `valor` (`float`) e `pais` (`str`) e retorna `True` se a transação for suspeita:
# valor maior que `5000` **e** país diferente de `"BR"`. Caso contrário, retorna `False`.

# %%
def transacao_suspeita(valor: float, pais: str) -> bool:
    # SUA SOLUÇÃO AQUI
    pass

# Casos de teste
print(transacao_suspeita(7200, "US"))   # True
print(transacao_suspeita(7200, "BR"))   # False
print(transacao_suspeita(300, "US"))    # False

# %% [markdown]
# ### Desafio 5 - `converter_entrada_segura`
#
# Recebe uma string que representa um número (ex: `"25"`) e retorna o valor convertido
# para `int`, somado a `1`. Se a string não puder ser convertida, retorne a string
# `"entrada invalida"` (sem usar `try/except`, que ainda veremos no Módulo 03 — use
# o que você já sabe sobre strings, como verificar se todos os caracteres são dígitos
# com `.isdigit()`).

# %%
def converter_entrada_segura(texto: str) -> str:
    # SUA SOLUÇÃO AQUI
    # dica: texto.isdigit() retorna True se todos os caracteres forem dígitos
    pass

# Casos de teste
print(converter_entrada_segura("25"))       # 26
print(converter_entrada_segura("vinte"))    # entrada invalida

# %% [markdown]
# ---
#
# Terminou? Compare suas soluções com `gabarito.py` e siga para
# `02_print_input.md`.
